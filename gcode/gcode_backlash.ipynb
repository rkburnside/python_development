# %% [markdown]
# # purpose:
# this code is intended to modify gcode to work better on a CNC etch a sketch. it's main purpose is to add backlash correction to the code. this is the most important part. the etch a sketch has a lot of internal backlash that can't be corrected. this code will identify when a direction change is made and correct for the backlash of that direction.

# %% [markdown]
# # features to develop
# - open file and read several lines
# - break them into variables
# - read several lines of code
# - determine when a direction change is made
# - remove all feed set operations
# - remove all Z operations
# - remove all comments
# - remove any other unnecessary gcode and clean it up (use the python library that already does some of this)

# %%
# open a file and read it
gcode = []
filename = 'ex1-circle.ngc'
f = open(filename, 'r')
for x in range(10):
    gcode.append(f.readline())
f.close()
print(gcode)
# Out:
# ['(Generated by PartKam Version 0.05)\n', '\n', 'G21 G90 G40\n', '\n', '(follow path 1)\n', 'G0 Z15\n', 'T0 M6\n', 'G17\n', 'M3\n', 'G0 X4.336040609137056 Y17.441116751269035\n']

# %%
print(gcode)
# Out:
# ['(Generated by PartKam Version 0.05)\n', '\n', 'G21 G90 G40\n', '\n', '(follow path 1)\n', 'G0 Z15\n', 'T0 M6\n', 'G17\n', 'M3\n', 'G0 X4.336040609137056 Y17.441116751269035\n']
