# %% [markdown]
# import pandas as pd
# import numpy as np
# print('hello')

# %%
# %matplotlib inline
import matplotlib as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()  # use Seaborn styles

# %%
# df = pd.read_excel('data_202004170756.xlsx')
df = pd.read_csv('data_202004171438.csv')
df.dtypes # give a list of all the indexes and their data types

# %%
# df[:14]
# df.columns
# df.index
# df.values
# df.values[:14]
# df['date_time'][0:10]
# df['serial'][0:10]
# df.iloc[:10,:3] # positional based indexing
# df.loc[:10,:'result'] # label based indexing
# df[df.result > 550]
# df['serial'][:10] > 1000000
# df['result'].median()
# df.sort_index?
# df['avg']=df['result']+df['result']
# df.head()
df.sort_values('date_time')

# %%
# df.pivot_table(values='result', index=['date_time','test'], columns='axis')
x = df.pivot_table(values='result', index=['date_time','test'], columns='axis')
x
# Out:
# axis                                                 Axis1       Axis2  \
# date_time           test
# 2015-02-25 14:07:20 Backlash                      0.130000    0.135000
#                     Edge1 Slew Rate             417.900000  427.775000
#                     Encoders after final Cal     -0.066400    0.000000
#                     Encoders after initial Cal    0.335250   -1.596375
#                     Final NVM Offsets             0.337500   -1.587500
#                     Initial NVM Offsets           0.262500   -1.587500
#                     Neg. Fin Cal Deflection     -22.999500  -23.148000
#                     Negative Stiffness          333.600000  319.700000
#                     Pos. Fin Cal Deflection      23.212100   22.963500
#                     Positive Stiffness          248.400000  306.700000
#                     Stall Torque                154.795000  164.395000
# 2015-02-26 10:05:16 Encoders after final Cal      6.183000   -0.084400
# ...

# %%
axes = plt.gca()
axes.set_xlim([xmin,xmax])
axes.set_ylim([ymin,ymax])

plt.figure(1, figsize = (8.5,11))
plt.suptitle('plot title')
ax = []
aPlot = plt.subplot(321, axisbg = 'w', title = "Year 1")
ax.append(aPlot)
plt.plot(paramValues,plotDataPrice[0], color = '#340B8C', 
     marker = 'o', ms = 5, mfc = '#EB1717')
plt.xticks(paramValues)
plt.ylabel('Average Price')
plt.xlabel('Mark-up')
plt.grid(True)
plt.ylim((25,250))

x.query('test == ["Positive Stiffness"]').plot()

# %%
# df['inverse'] = df['test'] / df['result']
df.iloc[10,4] = 5
df[:1]

# %%
df['date & time']

# %%
df.dtypes

# %%
df.sort_values(by=['test','serial #'])

# %%
df['axis #']

# %%
df.describe() # describes the data

# %%
df.columns # provides the columnes

# %%
# pd.pivot_table(df,values='result',index=['date & time', 'test', 'serial #', 'axis #'],aggfunc='mean')
test = pd.pivot_table(df,values='result',index=['test','axis #'],aggfunc='mean')
test

# %%
test.plot(df,x='axis #')

# %%
pw
